# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import matplotlib as mpl
import json as json

# %% [markdown]
# ### Funcion de iteracion del metodo de Schröeder aplicado al polinomio $p[z] := (z^2 - 1) (z - \lambda)$

# %%
S_z = lambda z, a : (a+z*(4*z**2+z*(-10+z**2)*a+4*a**2))/(1+3*z**4-4*z*(1+z**2)*a+2*(1+z**2)*a**2)

# %%
lambda_=0
roots=[1,-1,lambda_]
ratio=3
config={}
config['n_pixels']=3**6
config['x_min']=-ratio
config['x_max']=ratio
config['y_min']=-ratio
config['y_max']=ratio
config['nombre_archivo']='plano_infinito_SCH.png'
config['colors'] = ['magenta','cyan', 'yellow','black']
cmap = mpl.colors.ListedColormap(colors=config['colors'])
roots
# Out:
# [1, -1, 0]

# %%
xreal = np.linspace((config['x_min']), (config['x_max']),int(config['n_pixels']))
ximag = np.linspace(config['y_min'], config['y_max'],int(config['n_pixels']))
Xreal, Ximag = np.meshgrid(xreal, ximag)
X= Xreal+1j*Ximag 
tolerance = 0.0001
max_iter=200
poles=[-0.988781+0.93561j,0.+0.233266j,0.-0.771152j,0.988781+0.93561j]
# Dimensiones de la imagen
width, height = 1280, 720

# Densidad de píxeles
ppp = 73

# Crear la figura con las dimensiones y densidad de píxeles deseadas
fig = plt.figure(figsize=(width / ppp, height / ppp), dpi=ppp)
result_l=list()
for fila in X:
    fila_r=list()
    for elemento in fila:
        r_e=3
        z_0=elemento
        for i in range(max_iter):
            z_0=S_z(z_0,lambda_)
            encontrada=False
            for root in roots:
                if (np.abs(z_0-root)<tolerance):
                    r_e=roots.index(root)
                    encontrada=True
                    break
            if encontrada:
                break   
        fila_r.append(r_e)
    result_l.append(fila_r)
    
cmap = mpl.colors.ListedColormap(config['colors'])
plt.imshow(result_l,extent=(config['x_min'], config['x_max'],config['y_min'], config['y_max']), cmap=cmap)
plt.savefig('foto_guti.jpg',dpi=ppp, bbox_inches='tight')

# %%
plt.savefig('foto_guti.jpg',dpi=ppp)

# %%
def getNUms(matrix):
    elements=set()
    for fila in matrix:
        for elem in set(fila):
            elements.add(elem)
    print(elements)
getNUms(result_l)
# Out:
# {0, 1, 2}

# %%
f_iter((-0+0.1678013912187236j))
# Out:
# (-0+0.005883678833424077j)

# %%
z_0=-3.1389975178531238*1j
for i in range(100):
    print(f_iter(z_0))
    z_0=f_iter(z_0)
# Out:
# (-0-4.199026285453206j)
# (-0-5.131604436712216j)
# (-0-6.021563812323701j)
# (-0-6.894694406908899j)
# (-0-7.762124000498391j)
# (-0-8.62936699480237j)
# (-0-9.499328269840863j)
# (-0-10.373558650668752j)
# (-0-11.25285730669985j)
# (-0-12.137588386547696j)
# (-0-13.027858331987467j)
# (-0-13.923619759020962j)
# (-0-14.82473431643786j)
# (-0-15.731011588923534j)
# (-0-16.642233523995767j)
# (-0-17.55816987560732j)
# (-0-18.47858795775695j)
# (-0-19.403258738189002j)
# (-0-20.331960552184036j)
# (-0-21.26448125852933j)
# (-0-22.200619373601377j)
# (-0-23.140184537106045j)
# (-0-24.08299754481976j)
# (-0-25.02889010598227j)
# (-0-25.9777044313181j)
# (-0-26.929292722958895j)
# (-0-27.883516614046282j)
# (-0-28.84024658979712j)
# (-0-29.79936141087377j)
# (-0-30.760747552406997j)
# (-0-31.724298666883712j)
# (-0-32.6899150756051j)
# (-0-33.657503291039255j)
# (-0-34.626975570794826j)
# (-0-35.598249502887555j)
# (-0-36.571247621295804j)
# (-0-37.54589705038709j)
# ...

# %% [markdown]
# ## Familia Chebyshev-Halley con $\infty$ como punto fijo extrano super atractor

# %%
F_z = lambda z : (-2-3*z**2+z**4)/(z*(z**2-5))
roots=[1,-1]

# %%
ratio=1000
n_pixels=3**6
tolerance = 0.0001
max_iter=100
xreal = np.linspace(-ratio, ratio,n_pixels)
ximag = np.linspace(-ratio, ratio,n_pixels)
Xreal, Ximag = np.meshgrid(xreal, ximag)
X= Xreal+1j*Ximag 
colors = ['magenta','cyan', 'white']
width, height = 1280, 720

# Densidad de píxeles
ppp = 73

# Crear la figura con las dimensiones y densidad de píxeles deseadas
fig = plt.figure(figsize=(width / ppp, height / ppp), dpi=ppp)
result_l=list()
for fila in X:
    fila_r=list()
    for elemento in fila:
        r_e=3
        z_0=elemento
        for i in range(max_iter):
            z_0=F_z(z_0)
            encontrada=False
            for root in roots:
                if (np.abs(z_0-root)<tolerance):
                    r_e=roots.index(root)
                    encontrada=True
                    break
                elif (np.abs(z_0))>50:
                    r_e=2
                    encontrada=True
                    break
            if encontrada:
                break   
        fila_r.append(r_e)
    result_l.append(fila_r)
    
cmap = mpl.colors.ListedColormap(colors)
plt.imshow(result_l,extent=(-ratio, ratio,-ratio, ratio), cmap=cmap)
plt.savefig('foto_infi_indiferente_2.jpg',dpi=ppp, bbox_inches='tight')
# Out:
# C:\Users\Victor\AppData\Local\Temp/ipykernel_12040/3776996692.py:1: RuntimeWarning: divide by zero encountered in cdouble_scalars
#   F_z = lambda z : (-2-3*z**2+z**4)/(z*(z**2-5))
# C:\Users\Victor\AppData\Local\Temp/ipykernel_12040/3776996692.py:1: RuntimeWarning: invalid value encountered in cdouble_scalars
#   F_z = lambda z : (-2-3*z**2+z**4)/(z*(z**2-5))

# %%
F_z = lambda z : (z**6-3*z**3-1)/((z**2)*(z**3-4))
#F_z = lambda z : (3+6*z**2-z**4)/(8*z)

roots = np.roots([1, 0, 0, 1])

# %%
ratio=4
n_pixels=3**5
tolerance = 0.0001
max_iter=100
xreal = np.linspace(-ratio, ratio,n_pixels)
ximag = np.linspace(-ratio, ratio,n_pixels)
Xreal, Ximag = np.meshgrid(xreal, ximag)
X= Xreal+1j*Ximag 
colors = ['magenta','cyan','yellow', 'white']
width, height = 1280, 720

# Densidad de píxeles
ppp = 73

# Crear la figura con las dimensiones y densidad de píxeles deseadas
fig = plt.figure(figsize=(width / ppp, height / ppp), dpi=ppp)
result_l=list()
for fila in X:
    fila_r=list()
    for elemento in fila:
        r_e=3
        z_0=elemento
        for i in range(max_iter):
            
            z_0=F_z(z_0)
            encontrada=False
            for root in roots:
                if (np.abs(z_0-root)<tolerance):
                    r_e=roots.index(root)
                    encontrada=True
                    break
                elif (np.abs(z_0))>1000:
                    r_e=2
                    encontrada=True
                    break
            if encontrada:
                break   
        fila_r.append(r_e)
    result_l.append(fila_r)
    
cmap = mpl.colors.ListedColormap(colors)
plt.imshow(result_l,extent=(-ratio, ratio,-ratio, ratio), cmap=cmap)
plt.savefig('foto_infi_idiferente.jpg',dpi=ppp, bbox_inches='tight')
# Out:
# C:\Users\Victor\AppData\Local\Temp/ipykernel_10608/860446939.py:1: RuntimeWarning: divide by zero encountered in cdouble_scalars
#   F_z = lambda z : (z**6-3*z**3-1)/((z**2)*(z**3-4))
# C:\Users\Victor\AppData\Local\Temp/ipykernel_10608/860446939.py:1: RuntimeWarning: invalid value encountered in cdouble_scalars
#   F_z = lambda z : (z**6-3*z**3-1)/((z**2)*(z**3-4))
